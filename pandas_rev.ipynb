# %%
import pandas as pd

# %%
#series DataStructure
s=pd.Series([1,2,3,4,5,6])
s**2
# Out:
# 0     1
# 1     4
# 2     9
# 3    16
# 4    25
# 5    36
# dtype: int64

# %%
#DataFrame
info={
    "Name":["Rudra","B2K","vencwnzo"],
    "CGPA":[9.3,8.3,4.3]
}
df=pd.DataFrame(info)
df.columns
# Out:
# Index(['Name', 'CGPA'], dtype='object')

# %%
#Access the file
df=pd.read_csv("raw_data.csv")
# df.head(2)
# df.tail()
# df.info()
# df.describe()
# df[["age","id"]].describe()
# df["age"].describe()
# df.loc[0]
# df.loc[0:3]
df.at[0, "age"]
# Out:
# np.float64(29.0)

# %%
#filtering
df[df["age"]>30]
df.query("age>30")
# Out:
#     id          name   age country  gender   income
# 4    4  Maria Garcia  34.0   Spain  Female      NaN
# 6    6           NaN  45.0   India  Female  73000.0
# 7    7    Ahmed Khan  38.0     NaN    Male  68000.0
# 10  10   Emily Davis  31.0     USA     NaN  58000.0

# %%
#DataCleaning
df.isnull()
df.isnull().sum()
df.dropna()
df.fillna(0)
df.ffill()
df.bfill()
# Out:
#     id          name   age country   gender   income
# 0    1      John Doe  29.0     USA     Male  55000.0
# 1    1      John Doe  29.0     USA     Male  55000.0
# 2    2    Jane Smith  34.0  Canada   Female  62000.0
# 3    3          Alex  34.0     USA  Unknown  47000.0
# 4    4  Maria Garcia  34.0   Spain   Female  51000.0
# 5    5        Li Wei  27.0   China     Male  51000.0
# 6    6    Ahmed Khan  45.0   India   Female  73000.0
# 7    7    Ahmed Khan  38.0     USA     Male  68000.0
# 8    8    Rachel Lee  29.0     USA   Female  62000.0
# 9    9   Carlos Ruiz  31.0  Mexico     Male  45000.0
# 10  10   Emily Davis  31.0     USA      NaN  58000.0

# %%
#handel Duplicate
df.duplicated()
df.drop_duplicates()
# Out:
#     id          name   age country   gender   income
# 0    1      John Doe  29.0     USA     Male  55000.0
# 2    2    Jane Smith   NaN  Canada   Female  62000.0
# 3    3          Alex   NaN     USA  Unknown  47000.0
# 4    4  Maria Garcia  34.0   Spain   Female      NaN
# 5    5        Li Wei  27.0   China     Male  51000.0
# 6    6           NaN  45.0   India   Female  73000.0
# 7    7    Ahmed Khan  38.0     NaN     Male  68000.0
# 8    8    Rachel Lee  29.0     USA   Female  62000.0
# 9    9   Carlos Ruiz   NaN  Mexico     Male  45000.0
# 10  10   Emily Davis  31.0     USA      NaN  58000.0

# %%
#String Manupulation
df["gender"].str.upper()
df["name"].str.capitalize()
# Out:
# 0         John doe
# 1         John doe
# 2       Jane smith
# 3             Alex
# 4     Maria garcia
# 5           Li wei
# 6              NaN
# 7       Ahmed khan
# 8       Rachel lee
# 9      Carlos ruiz
# 10     Emily davis
# Name: name, dtype: object

# %%
#function
df["age"].apply(lambda x: x+10)
new={
    "Male":"M",
    "Female":"F"
}
df["gender"].map(new)
# Out:
# 0       M
# 1       M
# 2       F
# 3     NaN
# 4       F
# 5       M
# 6       F
# 7       M
# 8       F
# 9       M
# 10    NaN
# Name: gender, dtype: object

# %%
df["age"].sort_values()
# Out:
# 5     1.0
# 0     3.0
# 1     3.0
# 8     3.0
# 10    5.0
# 4     6.0
# 7     7.0
# 6     8.0
# 2     NaN
# 3     NaN
# 9     NaN
# Name: age, dtype: float64

# %%
#Grouping & Aggregation Methods
df.groupby("country")["age"].agg(["min","mean","max"])
# Out:
#           min  mean   max
# country
# Canada    NaN   NaN   NaN
# China    27.0  27.0  27.0
# India    45.0  45.0  45.0
# Mexico    NaN   NaN   NaN
# Spain    34.0  34.0  34.0
# USA      29.0  29.5  31.0

# %%
#Data_Visualization
# df["age"].hist()
df.plot(kind="scatter",x="age",y="income")
# Out:
# <Axes: xlabel='age', ylabel='income'>

# %%
cust={
    "id":[1,2,3],
    "Name":["Rudra","Ramm","cHIN2"]
}
order={
    "oid":[1,2,3],
    "Amnt":[100,200,300],
  
}
pd.concat(cust,order)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[63], line 10
#       1 cust={
#       2     "id":[1,2,3],
#       3     "Name":["Rudra","Ramm","cHIN2"]
#       4 }
#       5 order={
#       6     "oid":[1,2,3],
#       7     "Amnt":[100,200,300],
#       8
#       9 }
# ---> 10 pd.concat(cust,order)
#
# TypeError: concat() takes 1 positional argument but 2 were given
