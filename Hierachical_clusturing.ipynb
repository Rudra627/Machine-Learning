# %%
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt
from sklearn.datasets import load_iris
import seaborn as sns

# %%
df=load_iris()
X=df.data
Y=df.target
scale=StandardScaler()
X_scaled=scale.fit_transform(X)

# %%
sns.scatterplot(x=X[:,0],y=X[:,2])
# Out:
# <Axes: >

# %%
from scipy.cluster.hierarchy import linkage,dendrogram

#Create a Linkage metrix
z=linkage(X_scaled,method="ward")

dendrogram(z)
plt.figure(figsize=(12,6))
plt.xlabel("Sample")
plt.ylabel("distance")
plt.tittle("Dendrogram")

# %%
#Clusturing
from sklearn.cluster import AgglomerativeClustering
agg=AgglomerativeClustering(n_cluters=2)
agg.fit_predict(X_scaled)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[27], line 3
#       1 #Clusturing
#       2 from sklearn.cluster import AgglomerativeClustering
# ----> 3 agg=AgglomerativeClustering(n_cluters=2)
#       4 agg.fit_predict(X_scaled)
#
# TypeError: AgglomerativeClustering.__init__() got an unexpected keyword argument 'n_cluters'. Did you mean 'n_clusters'?
