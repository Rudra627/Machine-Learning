# %%
#1
import numpy as np
import pandas as pd
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn import metrics
import matplotlib.pyplot as plt
data={
    'x1':[2,5,6,8,10,11],
    'x2':[1,3,4,9,11,14],
    'y':[1.7,2.6,2.8,2.3,2.7,2.4]
}
df=pd.DataFrame(data)
df
x=df[['x1','x2']]
y=df['y']
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=100)

model = LinearRegression() # Instantiate the model
model.fit(x_train, y_train) # Fit the model

print("Intercept:", model.intercept_)
print("Coefficients:", model.coef_)
y_pred=model.predict(x_test)
print(y_pred)
print('Mean Absolute Error:', metrics.mean_absolute_error(y_test, y_pred))
print('Mean Squared Error:', metrics.mean_squared_error(y_test, y_pred))
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
# Out:
# Intercept: 1.0833333333333326
# Coefficients: [ 0.42575758 -0.24090909]
# [2.48939394 2.67424242]
# Mean Absolute Error: 0.11818181818181772
# Mean Squared Error: 0.014024334251606867
# Root Mean Squared Error: 0.11842438199799427

# %%
#2
import numpy as np
import pandas as pd
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn import metrics
data={
    'x1':[60,62,67,70,71,72,75,78],
    'x2':[22,25,24,20,15,14,14,11],
    'y':[140,155,159,179,192,200,212,215]
}
df=pd.DataFrame(data)
df
x=df[['x1','x2']]
y=df['y']
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=100)

model = LinearRegression() # Instantiate the model
model.fit(x_train, y_train) # Fit the model

print("Intercept:", model.intercept_)
print("Coefficients:", model.coef_)
y_pred=model.predict(x_test)
print(y_pred)
print('Mean Absolute Error:', metrics.mean_absolute_error(y_test, y_pred))
print('Mean Squared Error:', metrics.mean_squared_error(y_test, y_pred))
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
# Out:
# Intercept: -27.449818864886538
# Coefficients: [ 3.41714746 -1.68958809]
# [142.17362136 189.82382933 194.93056487]
# Mean Absolute Error: 6.690661478599225
# Mean Squared Error: 64.98362676361769
# Root Mean Squared Error: 8.06124225933061

# %%
#3
import numpy as np
import pandas as pd
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn import metrics
data={
    'x1':[1,2,3,4,5],
    'x2':[4,3,2,2,1],
    'y':[2,4,3,6,5]
}
df=pd.DataFrame(data)
df
x=df[['x1','x2']]
y=df['y']
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=100)

model = LinearRegression() # Instantiate the model
model.fit(x_train, y_train) # Fit the model

print("Intercept:", model.intercept_)
print("Coefficients:", model.coef_)
y_pred=model.predict(x_test)
print(y_pred)
print('Mean Absolute Error:', metrics.mean_absolute_error(y_test, y_pred))
print('Mean Squared Error:', metrics.mean_squared_error(y_test, y_pred))
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
# Out:
# Intercept: -32.00000000000002
# Coefficients: [6. 7.]
# [1. 0.]
# Mean Absolute Error: 3.0000000000000036
# Mean Squared Error: 9.000000000000021
# Root Mean Squared Error: 3.0000000000000036

# %%
#4
import numpy as np
import pandas as pd
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn import metrics
data={
    'x1':[7,1,11,11,7,11,3],
    'x2':[2.6,2.9,5.6,3.1,5.2,5.5,7.1],
    'y':[78.5,74.3,104.3,87.6,95.9,102.2,102.7]
}
df=pd.DataFrame(data)
df
x=df[['x1','x2']]
y=df['y']
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=100)

model = LinearRegression() # Instantiate the model
model.fit(x_train, y_train) # Fit the model

print("Intercept:", model.intercept_)
print("Coefficients:", model.coef_)
y_pred=model.predict(x_test)
print(y_pred)
print('Mean Absolute Error:', metrics.mean_absolute_error(y_test, y_pred))
print('Mean Squared Error:', metrics.mean_squared_error(y_test, y_pred))
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
# Out:
# Intercept: 51.00990663900413
# Coefficients: [1.44859959 6.67219917]
# [ 71.80788382 104.30881743 103.64159751]
# Mean Absolute Error: 1.3141770401106545
# Mean Squared Error: 2.762974732126986
# Root Mean Squared Error: 1.6622198206395524
